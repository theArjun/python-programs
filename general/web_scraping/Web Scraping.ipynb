# %% [markdown]
# # Web Scraping of Online Khabar

# %% [markdown]
# First import requests, bs4

# %%
import requests, bs4

# %%
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.onlinekhabar.com/')

# %%
type(res)
# Out:
# requests.models.Response

# %% [markdown]
# It is a requests object.

# %%
help(res)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...

# %%
print(res.text)
# Out:
# <!doctype html>
# <html lang="en-US">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="profile" href="https://gmpg.org/xfn/11">
# <title>Online Khabar &#8211; No 1 News Portal from Nepal in Nepali.</title>
# <link rel='dns-prefetch' href='//s7.addthis.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="Online Khabar &raquo; Feed" href="https://www.onlinekhabar.com/feed" />
# <link rel="alternate" type="application/rss+xml" title="Online Khabar &raquo; Comments Feed" href="https://www.onlinekhabar.com/comments/feed" />
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.onlinekhabar.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.0.4"}};
# ...

# %% [markdown]
# Remember to pass res.text, not res only. It accepts text format not requests object

# %%
soup = BeautifulSoup(res.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <title>
#    Online Khabar – No 1 News Portal from Nepal in Nepali.
#   </title>
#   <link href="//s7.addthis.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://www.onlinekhabar.com/feed" rel="alternate" title="Online Khabar » Feed" type="application/rss+xml"/>
#   <link href="https://www.onlinekhabar.com/comments/feed" rel="alternate" title="Online Khabar » Comments Feed" type="application/rss+xml"/>
#   <script type="text/javascript">
#    window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.onlinekhabar.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.0.4"}};
# ...

# %% [markdown]
# ## Links in Online Khabar

# %%
for links in soup.find_all('a',string = True):
    print(links.getText())
# Out:
# होमपेज
# समाचार
# विजनेश
# जीवनशैली
# सूचना प्रविधि
# मनोरन्जन
# प्रवास
# खेलकुद
# Add Comment
# Skip to content
# होमपेज
# समाचार
# विजनेश
# जीवनशैली
# सूचना प्रविधि
# मनोरन्जन
# प्रवास
# खेलकुद
#
# English
#
# क्रिस गेल र सन्दीपको रोचक संघर्ष
# दिल्ली ५ विकेटले विजयी, सबैभन्दा सफल बलर बने सन्दीप
# श्रीलंकामा श्रृङ्खलावद्ध विस्फोट, मृतकको संख्या १३७ पुग्यो
# कालीगण्डकी डाइभर्सन : शीर छेदन होस् तर, डाइभर्सन हुँदैन !
# महिलापीडित पुरुष पनि धेरै रहेछन् : उपमेयर सुशीला पाख्रिन
# नेकपाले ७७ जिल्लाका अध्यक्ष र सचिवको टुंगो लगायो
# समाजमा ‘डिभोर्स’को भोक जागेको छ (भिडियो वार्ता)
# चक्रपथको ‘डेडिकेटेड लेन’मा ठूला विद्युतीय बस चलाउन ४ वटा लगानी प्रस्ताव
# हिन्दू राष्ट्र माग्ने राप्रपालाई सरकारले वार्तामा बोलायो
# कसले पाउला नेविसंघको नेतृत्व ?
# नेकपाको पोलिटब्युरो र जिल्ला कमिटी घोषणा हुँदै, जनप्रतिनिधि पनि जिल्ला अध्यक्ष बन्न पाउने
# भूकम्पपछि फेरिएको बारपाकको रुप
# बैशाखसम्म दुई तिहाई खर्च गरिसक्न अर्थमन्त्रीको निर्देशन
# म्यानचेष्टर युनाइटेडमाथि इभर्टनको शानदार जित
# ...

# %% [markdown]
# ## Paragraphs in Online Khabar

# %%
for paragraphs in soup.find_all('p'):
    print(paragraphs.getText())
    print('\n'*2)
# Out:
# ८ वैशाख, जनकपुर । मलेसिया जान लागेका सिराहा नगरपालिकाका मनिष महराले ‘एजेन्ट’लाई ३० हजार रुपैयाँ दिए । रकम दिएको एक बर्ष नाघिसक्दा पनि उनी विदेश जान पाएनन् । न त रकम नै फिर्ता पाए । जनकपुरधाम-२५, लोहनाका चनरदीपले पनि विदेश जान भन्दै ‘एजेन्ट’लाई ३० हजार रुपैयाँ बुझाए । तर, उनी पनि अहिलेसम्म विदेश जान पाएका […]
#
#
#
#
#
#
#
# ८ वैशाख, बाग्लुङ । जिल्लाको काठेखोला गाउँपालिका–५ बिहुँमा आइतबार साँझ जन्ती बोकेको बस दुर्घटना हुँदा १ जनाको मृत्यु भएको छ । ५ जना घाइते भएका छन् । ताराखोला गाउँपालिका १ माझखर्कबाट जन्ती लिएर काठेखोला गाउँपालिका–८ लेखानी जाँदै गरेको ध १ ख ४६८ नम्बरको बस  बिहुँको भ्युटावरनजिकै सडकबाट खस्दा काठेखोला ८ का ६४ बर्षका गंगाबहादुर बिकको मृत्यु भएको […]
#
#
#
# ८ वैशाख, काठमाडौं । प्रहरीले त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलबाट ८५ लाख २७ हजार रुपैयाँ बराबरको सुनसहित दुई जनालाई पक्राउ गरेको छ । विमानस्थल सुरक्षा प्रहरी कार्यालयले एक किलो ६ सय...
#
#
#
#
#
#
#
# ...

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ded5ba42480f> in <module>
# ----> 1 s
#
# NameError: name 's' is not defined
